# %% [markdown]
# # Image Classification With Transfer Learning Using Keras

# %% [markdown]
# # Task 1: Importing Libraries

# %%
import tensorflow as tf
import tarfile
import urllib
import os
import numpy as np
import pets

from matplotlib import pyplot as plt
# %matplotlib inline

data_dir = 'data/'
if not os.path.isdir(data_dir):
    os.mkdir(data_dir)

print('TensorFlow version:', tf.__version__)
print('Is using GPU?', tf.test.is_gpu_available())
# Out:
# TensorFlow version: 2.0.1
# Is using GPU? False

# %% [markdown]
# # Task 2: Cats vs Dogs Dataset

# %%
pets.download_and_extract('data', '.')
# Out:
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %%
class_to_index = {'cat': 0, 'dog': 1}
index_to_class = {0: 'cat', 1: 'dog'}

train_annot, count_train = pets.cats_vs_dogs_annotations("data/annotations/trainval.txt")
test_annot, count_test = pets.cats_vs_dogs_annotations("data/annotations/test.txt")

print("Training examples: ", count_train)
print("Test examples: ", count_test)
# Out:
# Training examples:  3680
# Test examples:  3669

# %%
train_annot
# Out:
# {'Abyssinian_100.jpg': 'cat',
#  'Abyssinian_101.jpg': 'cat',
#  'Abyssinian_102.jpg': 'cat',
#  'Abyssinian_103.jpg': 'cat',
#  'Abyssinian_104.jpg': 'cat',
#  'Abyssinian_105.jpg': 'cat',
#  'Abyssinian_106.jpg': 'cat',
#  'Abyssinian_107.jpg': 'cat',
#  'Abyssinian_108.jpg': 'cat',
#  'Abyssinian_109.jpg': 'cat',
#  'Abyssinian_10.jpg': 'cat',
#  'Abyssinian_110.jpg': 'cat',
#  'Abyssinian_111.jpg': 'cat',
#  'Abyssinian_112.jpg': 'cat',
#  'Abyssinian_113.jpg': 'cat',
#  'Abyssinian_114.jpg': 'cat',
#  'Abyssinian_115.jpg': 'cat',
#  'Abyssinian_116.jpg': 'cat',
#  'Abyssinian_117.jpg': 'cat',
#  'Abyssinian_118.jpg': 'cat',
#  'Abyssinian_119.jpg': 'cat',
#  'Abyssinian_11.jpg': 'cat',
#  'Abyssinian_120.jpg': 'cat',
#  'Abyssinian_121.jpg': 'cat',
#  'Abyssinian_122.jpg': 'cat',
#  'Abyssinian_123.jpg': 'cat',
#  'Abyssinian_124.jpg': 'cat',
#  'Abyssinian_125.jpg': 'cat',
#  'Abyssinian_126.jpg': 'cat',
#  'Abyssinian_127.jpg': 'cat',
#  'Abyssinian_128.jpg': 'cat',
#  'Abyssinian_129.jpg': 'cat',
#  'Abyssinian_12.jpg': 'cat',
#  'Abyssinian_130.jpg': 'cat',
#  'Abyssinian_131.jpg': 'cat',
#  'Abyssinian_132.jpg': 'cat',
#  'Abyssinian_133.jpg': 'cat',
#  'Abyssinian_134.jpg': 'cat',
#  'Abyssinian_135.jpg': 'cat',
#  'Abyssinian_136.jpg': 'cat',
#  'Abyssinian_137.jpg': 'cat',
#  'Abyssinian_138.jpg': 'cat',
#  'Abyssinian_139.jpg': 'cat',
#  'Abyssinian_13.jpg': 'cat',
#  'Abyssinian_140.jpg': 'cat',
#  'Abyssinian_141.jpg': 'cat',
#  'Abyssinian_142.jpg': 'cat',
#  'Abyssinian_143.jpg': 'cat',
#  'Abyssinian_144.jpg': 'cat',
#  'Abyssinian_145.jpg': 'cat',
#  'american_bulldog_100.jpg': 'dog',
#  'american_bulldog_101.jpg': 'dog',
#  'american_bulldog_102.jpg': 'dog',
#  'american_bulldog_103.jpg': 'dog',
#  'american_bulldog_104.jpg': 'dog',
#  'american_bulldog_105.jpg': 'dog',
#  'american_bulldog_106.jpg': 'dog',
#  'american_bulldog_107.jpg': 'dog',
#  'american_bulldog_108.jpg': 'dog',
#  'american_bulldog_109.jpg': 'dog',
#  'american_bulldog_10.jpg': 'dog',
#  'american_bulldog_110.jpg': 'dog',
#  'american_bulldog_111.jpg': 'dog',
#  'american_bulldog_112.jpg': 'dog',
#  'american_bulldog_113.jpg': 'dog',
#  'american_bulldog_114.jpg': 'dog',
#  'american_bulldog_115.jpg': 'dog',
#  'american_bulldog_116.jpg': 'dog',
#  'american_bulldog_117.jpg': 'dog',
#  'american_bulldog_118.jpg': 'dog',
#  'american_bulldog_119.jpg': 'dog',
#  'american_bulldog_11.jpg': 'dog',
#  'american_bulldog_120.jpg': 'dog',
#  'american_bulldog_121.jpg': 'dog',
#  'american_bulldog_122.jpg': 'dog',
#  'american_bulldog_123.jpg': 'dog',
#  'american_bulldog_124.jpg': 'dog',
#  'american_bulldog_125.jpg': 'dog',
#  'american_bulldog_126.jpg': 'dog',
#  'american_bulldog_127.jpg': 'dog',
#  'american_bulldog_128.jpg': 'dog',
#  'american_bulldog_129.jpg': 'dog',
#  'american_bulldog_12.jpg': 'dog',
#  'american_bulldog_130.jpg': 'dog',
#  'american_bulldog_131.jpg': 'dog',
#  'american_bulldog_132.jpg': 'dog',
#  'american_bulldog_133.jpg': 'dog',
#  'american_bulldog_134.jpg': 'dog',
#  'american_bulldog_135.jpg': 'dog',
#  'american_bulldog_136.jpg': 'dog',
#  'american_bulldog_137.jpg': 'dog',
#  'american_bulldog_138.jpg': 'dog',
#  'american_bulldog_139.jpg': 'dog',
#  'american_bulldog_13.jpg': 'dog',
#  'american_bulldog_140.jpg': 'dog',
#  'american_bulldog_141.jpg': 'dog',
#  'american_bulldog_142.jpg': 'dog',
#  'american_bulldog_143.jpg': 'dog',
#  'american_bulldog_144.jpg': 'dog',
#  'american_bulldog_146.jpg': 'dog',
#  'american_pit_bull_terrier_100.jpg': 'dog',
#  'american_pit_bull_terrier_101.jpg': 'dog',
#  'american_pit_bull_terrier_102.jpg': 'dog',
#  'american_pit_bull_terrier_103.jpg': 'dog',
#  'american_pit_bull_terrier_104.jpg': 'dog',
#  'american_pit_bull_terrier_105.jpg': 'dog',
#  'american_pit_bull_terrier_106.jpg': 'dog',
#  'american_pit_bull_terrier_107.jpg': 'dog',
#  'american_pit_bull_terrier_108.jpg': 'dog',
#  'american_pit_bull_terrier_109.jpg': 'dog',
#  'american_pit_bull_terrier_10.jpg': 'dog',
#  'american_pit_bull_terrier_110.jpg': 'dog',
#  'american_pit_bull_terrier_111.jpg': 'dog',
#  'american_pit_bull_terrier_112.jpg': 'dog',
#  'american_pit_bull_terrier_113.jpg': 'dog',
#  'american_pit_bull_terrier_114.jpg': 'dog',
#  'american_pit_bull_terrier_115.jpg': 'dog',
#  'american_pit_bull_terrier_116.jpg': 'dog',
#  'american_pit_bull_terrier_117.jpg': 'dog',
#  'american_pit_bull_terrier_118.jpg': 'dog',
#  'american_pit_bull_terrier_119.jpg': 'dog',
#  'american_pit_bull_terrier_11.jpg': 'dog',
#  'american_pit_bull_terrier_120.jpg': 'dog',
#  'american_pit_bull_terrier_121.jpg': 'dog',
#  'american_pit_bull_terrier_122.jpg': 'dog',
#  'american_pit_bull_terrier_123.jpg': 'dog',
#  'american_pit_bull_terrier_124.jpg': 'dog',
#  'american_pit_bull_terrier_125.jpg': 'dog',
#  'american_pit_bull_terrier_126.jpg': 'dog',
#  'american_pit_bull_terrier_127.jpg': 'dog',
#  'american_pit_bull_terrier_128.jpg': 'dog',
#  'american_pit_bull_terrier_129.jpg': 'dog',
#  'american_pit_bull_terrier_12.jpg': 'dog',
#  'american_pit_bull_terrier_130.jpg': 'dog',
#  'american_pit_bull_terrier_131.jpg': 'dog',
#  'american_pit_bull_terrier_132.jpg': 'dog',
#  'american_pit_bull_terrier_133.jpg': 'dog',
#  'american_pit_bull_terrier_134.jpg': 'dog',
#  'american_pit_bull_terrier_135.jpg': 'dog',
#  'american_pit_bull_terrier_136.jpg': 'dog',
#  'american_pit_bull_terrier_137.jpg': 'dog',
#  'american_pit_bull_terrier_138.jpg': 'dog',
#  'american_pit_bull_terrier_139.jpg': 'dog',
#  'american_pit_bull_terrier_13.jpg': 'dog',
#  'american_pit_bull_terrier_140.jpg': 'dog',
#  'american_pit_bull_terrier_141.jpg': 'dog',
#  'american_pit_bull_terrier_142.jpg': 'dog',
#  'american_pit_bull_terrier_143.jpg': 'dog',
#  'american_pit_bull_terrier_144.jpg': 'dog',
#  'american_pit_bull_terrier_145.jpg': 'dog',
#  'basset_hound_100.jpg': 'dog',
#  'basset_hound_101.jpg': 'dog',
#  'basset_hound_102.jpg': 'dog',
#  'basset_hound_103.jpg': 'dog',
#  'basset_hound_104.jpg': 'dog',
#  'basset_hound_105.jpg': 'dog',
#  'basset_hound_106.jpg': 'dog',
#  'basset_hound_107.jpg': 'dog',
#  'basset_hound_108.jpg': 'dog',
#  'basset_hound_109.jpg': 'dog',
#  'basset_hound_10.jpg': 'dog',
#  'basset_hound_110.jpg': 'dog',
#  'basset_hound_111.jpg': 'dog',
#  'basset_hound_112.jpg': 'dog',
#  'basset_hound_113.jpg': 'dog',
#  'basset_hound_114.jpg': 'dog',
#  'basset_hound_115.jpg': 'dog',
#  'basset_hound_116.jpg': 'dog',
#  'basset_hound_117.jpg': 'dog',
#  'basset_hound_118.jpg': 'dog',
#  'basset_hound_119.jpg': 'dog',
#  'basset_hound_11.jpg': 'dog',
#  'basset_hound_120.jpg': 'dog',
#  'basset_hound_121.jpg': 'dog',
#  'basset_hound_122.jpg': 'dog',
#  'basset_hound_123.jpg': 'dog',
#  'basset_hound_124.jpg': 'dog',
#  'basset_hound_125.jpg': 'dog',
#  'basset_hound_126.jpg': 'dog',
#  'basset_hound_127.jpg': 'dog',
#  'basset_hound_128.jpg': 'dog',
#  'basset_hound_129.jpg': 'dog',
#  'basset_hound_12.jpg': 'dog',
#  'basset_hound_130.jpg': 'dog',
#  'basset_hound_131.jpg': 'dog',
#  'basset_hound_132.jpg': 'dog',
#  'basset_hound_133.jpg': 'dog',
#  'basset_hound_134.jpg': 'dog',
#  'basset_hound_135.jpg': 'dog',
#  'basset_hound_136.jpg': 'dog',
#  'basset_hound_137.jpg': 'dog',
#  'basset_hound_138.jpg': 'dog',
#  'basset_hound_139.jpg': 'dog',
#  'basset_hound_13.jpg': 'dog',
#  'basset_hound_140.jpg': 'dog',
#  'basset_hound_141.jpg': 'dog',
#  'basset_hound_142.jpg': 'dog',
#  'basset_hound_143.jpg': 'dog',
#  'basset_hound_144.jpg': 'dog',
#  'basset_hound_145.jpg': 'dog',
#  'beagle_100.jpg': 'dog',
#  'beagle_101.jpg': 'dog',
#  'beagle_102.jpg': 'dog',
#  'beagle_103.jpg': 'dog',
#  'beagle_104.jpg': 'dog',
#  'beagle_105.jpg': 'dog',
#  'beagle_107.jpg': 'dog',
#  'beagle_108.jpg': 'dog',
#  'beagle_109.jpg': 'dog',
#  'beagle_10.jpg': 'dog',
#  'beagle_110.jpg': 'dog',
#  'beagle_111.jpg': 'dog',
#  'beagle_112.jpg': 'dog',
#  'beagle_113.jpg': 'dog',
#  'beagle_114.jpg': 'dog',
#  'beagle_115.jpg': 'dog',
#  'beagle_116.jpg': 'dog',
#  'beagle_117.jpg': 'dog',
#  'beagle_118.jpg': 'dog',
#  'beagle_119.jpg': 'dog',
#  'beagle_120.jpg': 'dog',
#  'beagle_121.jpg': 'dog',
#  'beagle_122.jpg': 'dog',
#  'beagle_123.jpg': 'dog',
#  'beagle_124.jpg': 'dog',
#  'beagle_125.jpg': 'dog',
#  'beagle_126.jpg': 'dog',
#  'beagle_127.jpg': 'dog',
#  'beagle_128.jpg': 'dog',
#  'beagle_129.jpg': 'dog',
#  'beagle_12.jpg': 'dog',
#  'beagle_130.jpg': 'dog',
#  'beagle_131.jpg': 'dog',
#  'beagle_133.jpg': 'dog',
#  'beagle_134.jpg': 'dog',
#  'beagle_135.jpg': 'dog',
#  'beagle_136.jpg': 'dog',
#  'beagle_137.jpg': 'dog',
#  'beagle_138.jpg': 'dog',
#  'beagle_139.jpg': 'dog',
#  'beagle_13.jpg': 'dog',
#  'beagle_140.jpg': 'dog',
#  'beagle_141.jpg': 'dog',
#  'beagle_142.jpg': 'dog',
#  'beagle_143.jpg': 'dog',
#  'beagle_144.jpg': 'dog',
#  'beagle_145.jpg': 'dog',
#  'beagle_146.jpg': 'dog',
#  'beagle_147.jpg': 'dog',
#  'beagle_148.jpg': 'dog',
#  'Bengal_100.jpg': 'cat',
#  'Bengal_101.jpg': 'cat',
#  'Bengal_102.jpg': 'cat',
#  'Bengal_103.jpg': 'cat',
#  'Bengal_104.jpg': 'cat',
#  'Bengal_105.jpg': 'cat',
#  'Bengal_106.jpg': 'cat',
#  'Bengal_107.jpg': 'cat',
#  'Bengal_108.jpg': 'cat',
#  'Bengal_109.jpg': 'cat',
#  'Bengal_10.jpg': 'cat',
#  'Bengal_110.jpg': 'cat',
#  'Bengal_111.jpg': 'cat',
#  'Bengal_112.jpg': 'cat',
#  'Bengal_113.jpg': 'cat',
#  'Bengal_114.jpg': 'cat',
#  'Bengal_115.jpg': 'cat',
#  'Bengal_116.jpg': 'cat',
#  'Bengal_117.jpg': 'cat',
#  'Bengal_118.jpg': 'cat',
#  'Bengal_119.jpg': 'cat',
#  'Bengal_11.jpg': 'cat',
#  'Bengal_120.jpg': 'cat',
#  'Bengal_121.jpg': 'cat',
#  'Bengal_122.jpg': 'cat',
#  'Bengal_123.jpg': 'cat',
#  'Bengal_124.jpg': 'cat',
#  'Bengal_125.jpg': 'cat',
#  'Bengal_126.jpg': 'cat',
#  'Bengal_127.jpg': 'cat',
#  'Bengal_128.jpg': 'cat',
#  'Bengal_129.jpg': 'cat',
#  'Bengal_12.jpg': 'cat',
#  'Bengal_130.jpg': 'cat',
#  'Bengal_131.jpg': 'cat',
#  'Bengal_132.jpg': 'cat',
#  'Bengal_133.jpg': 'cat',
#  'Bengal_134.jpg': 'cat',
#  'Bengal_135.jpg': 'cat',
#  'Bengal_136.jpg': 'cat',
#  'Bengal_137.jpg': 'cat',
#  'Bengal_138.jpg': 'cat',
#  'Bengal_139.jpg': 'cat',
#  'Bengal_13.jpg': 'cat',
#  'Bengal_140.jpg': 'cat',
#  'Bengal_141.jpg': 'cat',
#  'Bengal_142.jpg': 'cat',
#  'Bengal_143.jpg': 'cat',
#  'Bengal_144.jpg': 'cat',
#  'Bengal_145.jpg': 'cat',
#  'Birman_100.jpg': 'cat',
#  'Birman_101.jpg': 'cat',
#  'Birman_102.jpg': 'cat',
#  'Birman_103.jpg': 'cat',
#  'Birman_104.jpg': 'cat',
#  'Birman_105.jpg': 'cat',
#  'Birman_106.jpg': 'cat',
#  'Birman_107.jpg': 'cat',
#  'Birman_108.jpg': 'cat',
#  'Birman_109.jpg': 'cat',
#  'Birman_10.jpg': 'cat',
#  'Birman_110.jpg': 'cat',
#  'Birman_111.jpg': 'cat',
#  'Birman_112.jpg': 'cat',
#  'Birman_113.jpg': 'cat',
#  'Birman_114.jpg': 'cat',
#  'Birman_115.jpg': 'cat',
#  'Birman_116.jpg': 'cat',
#  'Birman_117.jpg': 'cat',
#  'Birman_118.jpg': 'cat',
#  'Birman_119.jpg': 'cat',
#  'Birman_11.jpg': 'cat',
#  'Birman_120.jpg': 'cat',
#  'Birman_121.jpg': 'cat',
#  'Birman_122.jpg': 'cat',
#  'Birman_123.jpg': 'cat',
#  'Birman_124.jpg': 'cat',
#  'Birman_125.jpg': 'cat',
#  'Birman_126.jpg': 'cat',
#  'Birman_127.jpg': 'cat',
#  'Birman_128.jpg': 'cat',
#  'Birman_129.jpg': 'cat',
#  'Birman_12.jpg': 'cat',
#  'Birman_130.jpg': 'cat',
#  'Birman_131.jpg': 'cat',
#  'Birman_132.jpg': 'cat',
#  'Birman_133.jpg': 'cat',
#  'Birman_134.jpg': 'cat',
#  'Birman_135.jpg': 'cat',
#  'Birman_136.jpg': 'cat',
#  'Birman_137.jpg': 'cat',
#  'Birman_138.jpg': 'cat',
#  'Birman_139.jpg': 'cat',
#  'Birman_13.jpg': 'cat',
#  'Birman_140.jpg': 'cat',
#  'Birman_141.jpg': 'cat',
#  'Birman_142.jpg': 'cat',
#  'Birman_143.jpg': 'cat',
#  'Birman_144.jpg': 'cat',
#  'Birman_145.jpg': 'cat',
#  'Bombay_100.jpg': 'cat',
#  'Bombay_101.jpg': 'cat',
#  'Bombay_102.jpg': 'cat',
#  'Bombay_103.jpg': 'cat',
#  'Bombay_104.jpg': 'cat',
#  'Bombay_105.jpg': 'cat',
#  'Bombay_106.jpg': 'cat',
#  'Bombay_107.jpg': 'cat',
#  'Bombay_108.jpg': 'cat',
#  'Bombay_109.jpg': 'cat',
#  'Bombay_10.jpg': 'cat',
#  'Bombay_110.jpg': 'cat',
#  'Bombay_111.jpg': 'cat',
#  'Bombay_112.jpg': 'cat',
#  'Bombay_113.jpg': 'cat',
#  'Bombay_114.jpg': 'cat',
#  'Bombay_115.jpg': 'cat',
#  'Bombay_116.jpg': 'cat',
#  'Bombay_117.jpg': 'cat',
#  'Bombay_118.jpg': 'cat',
#  'Bombay_119.jpg': 'cat',
#  'Bombay_120.jpg': 'cat',
#  'Bombay_121.jpg': 'cat',
#  'Bombay_122.jpg': 'cat',
#  'Bombay_123.jpg': 'cat',
#  'Bombay_125.jpg': 'cat',
#  'Bombay_126.jpg': 'cat',
#  'Bombay_127.jpg': 'cat',
#  'Bombay_128.jpg': 'cat',
#  'Bombay_129.jpg': 'cat',
#  'Bombay_12.jpg': 'cat',
#  'Bombay_130.jpg': 'cat',
#  'Bombay_131.jpg': 'cat',
#  'Bombay_132.jpg': 'cat',
#  'Bombay_133.jpg': 'cat',
#  'Bombay_134.jpg': 'cat',
#  'Bombay_135.jpg': 'cat',
#  'Bombay_136.jpg': 'cat',
#  'Bombay_137.jpg': 'cat',
#  'Bombay_138.jpg': 'cat',
#  'Bombay_139.jpg': 'cat',
#  'Bombay_13.jpg': 'cat',
#  'Bombay_140.jpg': 'cat',
#  'Bombay_141.jpg': 'cat',
#  'Bombay_143.jpg': 'cat',
#  'Bombay_144.jpg': 'cat',
#  'Bombay_145.jpg': 'cat',
#  'Bombay_146.jpg': 'cat',
#  'Bombay_148.jpg': 'cat',
#  'boxer_100.jpg': 'dog',
#  'boxer_101.jpg': 'dog',
#  'boxer_102.jpg': 'dog',
#  'boxer_103.jpg': 'dog',
#  'boxer_104.jpg': 'dog',
#  'boxer_105.jpg': 'dog',
#  'boxer_106.jpg': 'dog',
#  'boxer_107.jpg': 'dog',
#  'boxer_108.jpg': 'dog',
#  'boxer_109.jpg': 'dog',
#  'boxer_10.jpg': 'dog',
#  'boxer_110.jpg': 'dog',
#  'boxer_111.jpg': 'dog',
#  'boxer_112.jpg': 'dog',
#  'boxer_113.jpg': 'dog',
#  'boxer_114.jpg': 'dog',
#  'boxer_115.jpg': 'dog',
#  'boxer_116.jpg': 'dog',
#  'boxer_117.jpg': 'dog',
#  'boxer_118.jpg': 'dog',
#  'boxer_119.jpg': 'dog',
#  'boxer_11.jpg': 'dog',
#  'boxer_120.jpg': 'dog',
#  'boxer_121.jpg': 'dog',
#  'boxer_122.jpg': 'dog',
#  'boxer_123.jpg': 'dog',
#  'boxer_124.jpg': 'dog',
#  'boxer_125.jpg': 'dog',
#  'boxer_126.jpg': 'dog',
#  'boxer_127.jpg': 'dog',
#  'boxer_128.jpg': 'dog',
#  'boxer_129.jpg': 'dog',
#  'boxer_12.jpg': 'dog',
#  'boxer_130.jpg': 'dog',
#  'boxer_131.jpg': 'dog',
#  'boxer_132.jpg': 'dog',
#  'boxer_133.jpg': 'dog',
#  'boxer_134.jpg': 'dog',
#  'boxer_135.jpg': 'dog',
#  'boxer_136.jpg': 'dog',
#  'boxer_137.jpg': 'dog',
#  'boxer_138.jpg': 'dog',
#  'boxer_139.jpg': 'dog',
#  'boxer_13.jpg': 'dog',
#  'boxer_140.jpg': 'dog',
#  'boxer_141.jpg': 'dog',
#  'boxer_142.jpg': 'dog',
#  'boxer_143.jpg': 'dog',
#  'boxer_144.jpg': 'dog',
#  'boxer_145.jpg': 'dog',
#  'British_Shorthair_100.jpg': 'cat',
#  'British_Shorthair_101.jpg': 'cat',
#  'British_Shorthair_102.jpg': 'cat',
#  'British_Shorthair_103.jpg': 'cat',
#  'British_Shorthair_104.jpg': 'cat',
#  'British_Shorthair_105.jpg': 'cat',
#  'British_Shorthair_106.jpg': 'cat',
#  'British_Shorthair_107.jpg': 'cat',
#  'British_Shorthair_108.jpg': 'cat',
#  'British_Shorthair_109.jpg': 'cat',
#  'British_Shorthair_10.jpg': 'cat',
#  'British_Shorthair_110.jpg': 'cat',
#  'British_Shorthair_111.jpg': 'cat',
#  'British_Shorthair_112.jpg': 'cat',
#  'British_Shorthair_113.jpg': 'cat',
#  'British_Shorthair_114.jpg': 'cat',
#  'British_Shorthair_115.jpg': 'cat',
#  'British_Shorthair_116.jpg': 'cat',
#  'British_Shorthair_117.jpg': 'cat',
#  'British_Shorthair_118.jpg': 'cat',
#  'British_Shorthair_119.jpg': 'cat',
#  'British_Shorthair_120.jpg': 'cat',
#  'British_Shorthair_121.jpg': 'cat',
#  'British_Shorthair_122.jpg': 'cat',
#  'British_Shorthair_123.jpg': 'cat',
#  'British_Shorthair_124.jpg': 'cat',
#  'British_Shorthair_125.jpg': 'cat',
#  'British_Shorthair_126.jpg': 'cat',
#  'British_Shorthair_127.jpg': 'cat',
#  'British_Shorthair_128.jpg': 'cat',
#  'British_Shorthair_129.jpg': 'cat',
#  'British_Shorthair_130.jpg': 'cat',
#  'British_Shorthair_133.jpg': 'cat',
#  'British_Shorthair_134.jpg': 'cat',
#  'British_Shorthair_135.jpg': 'cat',
#  'British_Shorthair_136.jpg': 'cat',
#  'British_Shorthair_137.jpg': 'cat',
#  'British_Shorthair_139.jpg': 'cat',
#  'British_Shorthair_140.jpg': 'cat',
#  'British_Shorthair_141.jpg': 'cat',
#  'British_Shorthair_144.jpg': 'cat',
#  'British_Shorthair_145.jpg': 'cat',
#  'British_Shorthair_148.jpg': 'cat',
#  'British_Shorthair_149.jpg': 'cat',
#  'British_Shorthair_151.jpg': 'cat',
#  'British_Shorthair_153.jpg': 'cat',
#  'British_Shorthair_154.jpg': 'cat',
#  'British_Shorthair_155.jpg': 'cat',
#  'British_Shorthair_156.jpg': 'cat',
#  'British_Shorthair_157.jpg': 'cat',
#  'chihuahua_100.jpg': 'dog',
#  'chihuahua_101.jpg': 'dog',
#  'chihuahua_102.jpg': 'dog',
#  'chihuahua_103.jpg': 'dog',
#  'chihuahua_104.jpg': 'dog',
#  'chihuahua_105.jpg': 'dog',
#  'chihuahua_106.jpg': 'dog',
#  'chihuahua_107.jpg': 'dog',
#  'chihuahua_108.jpg': 'dog',
#  'chihuahua_109.jpg': 'dog',
#  'chihuahua_10.jpg': 'dog',
#  'chihuahua_110.jpg': 'dog',
#  'chihuahua_111.jpg': 'dog',
#  'chihuahua_112.jpg': 'dog',
#  'chihuahua_113.jpg': 'dog',
#  'chihuahua_114.jpg': 'dog',
#  'chihuahua_115.jpg': 'dog',
#  'chihuahua_116.jpg': 'dog',
#  'chihuahua_117.jpg': 'dog',
#  'chihuahua_118.jpg': 'dog',
#  'chihuahua_119.jpg': 'dog',
#  'chihuahua_11.jpg': 'dog',
#  'chihuahua_120.jpg': 'dog',
#  'chihuahua_121.jpg': 'dog',
#  'chihuahua_122.jpg': 'dog',
#  'chihuahua_123.jpg': 'dog',
#  'chihuahua_124.jpg': 'dog',
#  'chihuahua_125.jpg': 'dog',
#  'chihuahua_126.jpg': 'dog',
#  'chihuahua_127.jpg': 'dog',
#  'chihuahua_128.jpg': 'dog',
#  'chihuahua_129.jpg': 'dog',
#  'chihuahua_12.jpg': 'dog',
#  'chihuahua_130.jpg': 'dog',
#  'chihuahua_131.jpg': 'dog',
#  'chihuahua_132.jpg': 'dog',
#  'chihuahua_133.jpg': 'dog',
#  'chihuahua_134.jpg': 'dog',
#  'chihuahua_135.jpg': 'dog',
#  'chihuahua_136.jpg': 'dog',
#  'chihuahua_137.jpg': 'dog',
#  'chihuahua_138.jpg': 'dog',
#  'chihuahua_139.jpg': 'dog',
#  'chihuahua_13.jpg': 'dog',
#  'chihuahua_140.jpg': 'dog',
#  'chihuahua_141.jpg': 'dog',
#  'chihuahua_142.jpg': 'dog',
#  'chihuahua_143.jpg': 'dog',
#  'chihuahua_144.jpg': 'dog',
#  'chihuahua_145.jpg': 'dog',
#  'Egyptian_Mau_100.jpg': 'cat',
#  'Egyptian_Mau_101.jpg': 'cat',
#  'Egyptian_Mau_102.jpg': 'cat',
#  'Egyptian_Mau_103.jpg': 'cat',
#  'Egyptian_Mau_104.jpg': 'cat',
#  'Egyptian_Mau_105.jpg': 'cat',
#  'Egyptian_Mau_106.jpg': 'cat',
#  'Egyptian_Mau_107.jpg': 'cat',
#  'Egyptian_Mau_108.jpg': 'cat',
#  'Egyptian_Mau_109.jpg': 'cat',
#  'Egyptian_Mau_10.jpg': 'cat',
#  'Egyptian_Mau_110.jpg': 'cat',
#  'Egyptian_Mau_111.jpg': 'cat',
#  'Egyptian_Mau_112.jpg': 'cat',
#  'Egyptian_Mau_113.jpg': 'cat',
#  'Egyptian_Mau_114.jpg': 'cat',
#  'Egyptian_Mau_115.jpg': 'cat',
#  'Egyptian_Mau_116.jpg': 'cat',
#  'Egyptian_Mau_117.jpg': 'cat',
#  'Egyptian_Mau_118.jpg': 'cat',
#  'Egyptian_Mau_119.jpg': 'cat',
#  'Egyptian_Mau_11.jpg': 'cat',
#  'Egyptian_Mau_120.jpg': 'cat',
#  'Egyptian_Mau_121.jpg': 'cat',
#  'Egyptian_Mau_122.jpg': 'cat',
#  'Egyptian_Mau_123.jpg': 'cat',
#  'Egyptian_Mau_124.jpg': 'cat',
#  'Egyptian_Mau_125.jpg': 'cat',
#  'Egyptian_Mau_126.jpg': 'cat',
#  'Egyptian_Mau_127.jpg': 'cat',
#  'Egyptian_Mau_128.jpg': 'cat',
#  'Egyptian_Mau_12.jpg': 'cat',
#  'Egyptian_Mau_130.jpg': 'cat',
#  'Egyptian_Mau_131.jpg': 'cat',
#  'Egyptian_Mau_132.jpg': 'cat',
#  'Egyptian_Mau_133.jpg': 'cat',
#  'Egyptian_Mau_134.jpg': 'cat',
#  'Egyptian_Mau_136.jpg': 'cat',
#  'Egyptian_Mau_138.jpg': 'cat',
#  'Egyptian_Mau_13.jpg': 'cat',
#  'Egyptian_Mau_140.jpg': 'cat',
#  'Egyptian_Mau_141.jpg': 'cat',
#  'Egyptian_Mau_142.jpg': 'cat',
#  'Egyptian_Mau_143.jpg': 'cat',
#  'Egyptian_Mau_144.jpg': 'cat',
#  'Egyptian_Mau_146.jpg': 'cat',
#  'Egyptian_Mau_147.jpg': 'cat',
#  'english_cocker_spaniel_100.jpg': 'dog',
#  'english_cocker_spaniel_101.jpg': 'dog',
#  'english_cocker_spaniel_102.jpg': 'dog',
#  'english_cocker_spaniel_103.jpg': 'dog',
#  'english_cocker_spaniel_104.jpg': 'dog',
#  'english_cocker_spaniel_105.jpg': 'dog',
#  'english_cocker_spaniel_106.jpg': 'dog',
#  'english_cocker_spaniel_107.jpg': 'dog',
#  'english_cocker_spaniel_108.jpg': 'dog',
#  'english_cocker_spaniel_109.jpg': 'dog',
#  'english_cocker_spaniel_10.jpg': 'dog',
#  'english_cocker_spaniel_110.jpg': 'dog',
#  'english_cocker_spaniel_111.jpg': 'dog',
#  'english_cocker_spaniel_112.jpg': 'dog',
#  'english_cocker_spaniel_113.jpg': 'dog',
#  'english_cocker_spaniel_114.jpg': 'dog',
#  'english_cocker_spaniel_115.jpg': 'dog',
#  'english_cocker_spaniel_116.jpg': 'dog',
#  'english_cocker_spaniel_117.jpg': 'dog',
#  'english_cocker_spaniel_118.jpg': 'dog',
#  'english_cocker_spaniel_119.jpg': 'dog',
#  'english_cocker_spaniel_11.jpg': 'dog',
#  'english_cocker_spaniel_120.jpg': 'dog',
#  'english_cocker_spaniel_121.jpg': 'dog',
#  'english_cocker_spaniel_122.jpg': 'dog',
#  'english_cocker_spaniel_123.jpg': 'dog',
#  'english_cocker_spaniel_124.jpg': 'dog',
#  'english_cocker_spaniel_125.jpg': 'dog',
#  'english_cocker_spaniel_126.jpg': 'dog',
#  'english_cocker_spaniel_127.jpg': 'dog',
#  'english_cocker_spaniel_128.jpg': 'dog',
#  'english_cocker_spaniel_129.jpg': 'dog',
#  'english_cocker_spaniel_12.jpg': 'dog',
#  'english_cocker_spaniel_130.jpg': 'dog',
#  'english_cocker_spaniel_131.jpg': 'dog',
#  'english_cocker_spaniel_132.jpg': 'dog',
#  'english_cocker_spaniel_133.jpg': 'dog',
#  'english_cocker_spaniel_134.jpg': 'dog',
#  'english_cocker_spaniel_135.jpg': 'dog',
#  'english_cocker_spaniel_136.jpg': 'dog',
#  'english_cocker_spaniel_137.jpg': 'dog',
#  'english_cocker_spaniel_138.jpg': 'dog',
#  'english_cocker_spaniel_139.jpg': 'dog',
#  'english_cocker_spaniel_13.jpg': 'dog',
#  'english_cocker_spaniel_140.jpg': 'dog',
#  'english_cocker_spaniel_141.jpg': 'dog',
#  'english_cocker_spaniel_142.jpg': 'dog',
#  'english_cocker_spaniel_143.jpg': 'dog',
#  'english_cocker_spaniel_144.jpg': 'dog',
#  'english_cocker_spaniel_145.jpg': 'dog',
#  'english_setter_100.jpg': 'dog',
#  'english_setter_101.jpg': 'dog',
#  'english_setter_102.jpg': 'dog',
#  'english_setter_103.jpg': 'dog',
#  'english_setter_104.jpg': 'dog',
#  'english_setter_105.jpg': 'dog',
#  'english_setter_106.jpg': 'dog',
#  'english_setter_107.jpg': 'dog',
#  'english_setter_108.jpg': 'dog',
#  'english_setter_109.jpg': 'dog',
#  'english_setter_10.jpg': 'dog',
#  'english_setter_110.jpg': 'dog',
#  'english_setter_111.jpg': 'dog',
#  'english_setter_112.jpg': 'dog',
#  'english_setter_113.jpg': 'dog',
#  'english_setter_114.jpg': 'dog',
#  'english_setter_115.jpg': 'dog',
#  'english_setter_116.jpg': 'dog',
#  'english_setter_117.jpg': 'dog',
#  'english_setter_118.jpg': 'dog',
#  'english_setter_119.jpg': 'dog',
#  'english_setter_11.jpg': 'dog',
#  'english_setter_120.jpg': 'dog',
#  'english_setter_121.jpg': 'dog',
#  'english_setter_122.jpg': 'dog',
#  'english_setter_123.jpg': 'dog',
#  'english_setter_124.jpg': 'dog',
#  'english_setter_125.jpg': 'dog',
#  'english_setter_126.jpg': 'dog',
#  'english_setter_127.jpg': 'dog',
#  'english_setter_128.jpg': 'dog',
#  'english_setter_129.jpg': 'dog',
#  'english_setter_12.jpg': 'dog',
#  'english_setter_130.jpg': 'dog',
#  'english_setter_131.jpg': 'dog',
#  'english_setter_132.jpg': 'dog',
#  'english_setter_133.jpg': 'dog',
#  'english_setter_134.jpg': 'dog',
#  'english_setter_135.jpg': 'dog',
#  'english_setter_136.jpg': 'dog',
#  'english_setter_137.jpg': 'dog',
#  'english_setter_138.jpg': 'dog',
#  'english_setter_139.jpg': 'dog',
#  'english_setter_13.jpg': 'dog',
#  'english_setter_140.jpg': 'dog',
#  'english_setter_141.jpg': 'dog',
#  'english_setter_142.jpg': 'dog',
#  'english_setter_143.jpg': 'dog',
#  'english_setter_144.jpg': 'dog',
#  'english_setter_145.jpg': 'dog',
#  'german_shorthaired_100.jpg': 'dog',
#  'german_shorthaired_101.jpg': 'dog',
#  'german_shorthaired_102.jpg': 'dog',
#  'german_shorthaired_103.jpg': 'dog',
#  'german_shorthaired_104.jpg': 'dog',
#  'german_shorthaired_105.jpg': 'dog',
#  'german_shorthaired_106.jpg': 'dog',
#  'german_shorthaired_107.jpg': 'dog',
#  'german_shorthaired_108.jpg': 'dog',
#  'german_shorthaired_109.jpg': 'dog',
#  'german_shorthaired_10.jpg': 'dog',
#  'german_shorthaired_110.jpg': 'dog',
#  'german_shorthaired_111.jpg': 'dog',
#  'german_shorthaired_112.jpg': 'dog',
#  'german_shorthaired_113.jpg': 'dog',
#  'german_shorthaired_114.jpg': 'dog',
#  'german_shorthaired_115.jpg': 'dog',
#  'german_shorthaired_116.jpg': 'dog',
#  'german_shorthaired_117.jpg': 'dog',
#  'german_shorthaired_118.jpg': 'dog',
#  'german_shorthaired_119.jpg': 'dog',
#  'german_shorthaired_11.jpg': 'dog',
#  'german_shorthaired_120.jpg': 'dog',
#  'german_shorthaired_121.jpg': 'dog',
#  'german_shorthaired_122.jpg': 'dog',
#  'german_shorthaired_123.jpg': 'dog',
#  'german_shorthaired_124.jpg': 'dog',
#  'german_shorthaired_125.jpg': 'dog',
#  'german_shorthaired_126.jpg': 'dog',
#  'german_shorthaired_127.jpg': 'dog',
#  'german_shorthaired_128.jpg': 'dog',
#  'german_shorthaired_129.jpg': 'dog',
#  'german_shorthaired_12.jpg': 'dog',
#  'german_shorthaired_130.jpg': 'dog',
#  'german_shorthaired_131.jpg': 'dog',
#  'german_shorthaired_132.jpg': 'dog',
#  'german_shorthaired_133.jpg': 'dog',
#  'german_shorthaired_134.jpg': 'dog',
#  'german_shorthaired_135.jpg': 'dog',
#  'german_shorthaired_136.jpg': 'dog',
#  'german_shorthaired_137.jpg': 'dog',
#  'german_shorthaired_138.jpg': 'dog',
#  'german_shorthaired_139.jpg': 'dog',
#  'german_shorthaired_13.jpg': 'dog',
#  'german_shorthaired_140.jpg': 'dog',
#  'german_shorthaired_141.jpg': 'dog',
#  'german_shorthaired_142.jpg': 'dog',
#  'german_shorthaired_143.jpg': 'dog',
#  'german_shorthaired_144.jpg': 'dog',
#  'german_shorthaired_145.jpg': 'dog',
#  'great_pyrenees_100.jpg': 'dog',
#  'great_pyrenees_101.jpg': 'dog',
#  'great_pyrenees_102.jpg': 'dog',
#  'great_pyrenees_103.jpg': 'dog',
#  'great_pyrenees_104.jpg': 'dog',
#  'great_pyrenees_105.jpg': 'dog',
#  'great_pyrenees_106.jpg': 'dog',
#  'great_pyrenees_107.jpg': 'dog',
#  'great_pyrenees_108.jpg': 'dog',
#  'great_pyrenees_109.jpg': 'dog',
#  'great_pyrenees_10.jpg': 'dog',
#  'great_pyrenees_110.jpg': 'dog',
#  'great_pyrenees_111.jpg': 'dog',
#  'great_pyrenees_112.jpg': 'dog',
#  'great_pyrenees_113.jpg': 'dog',
#  'great_pyrenees_114.jpg': 'dog',
#  'great_pyrenees_115.jpg': 'dog',
#  'great_pyrenees_116.jpg': 'dog',
#  'great_pyrenees_117.jpg': 'dog',
#  'great_pyrenees_118.jpg': 'dog',
#  'great_pyrenees_119.jpg': 'dog',
#  'great_pyrenees_11.jpg': 'dog',
#  'great_pyrenees_120.jpg': 'dog',
#  'great_pyrenees_121.jpg': 'dog',
#  'great_pyrenees_122.jpg': 'dog',
#  'great_pyrenees_123.jpg': 'dog',
#  'great_pyrenees_124.jpg': 'dog',
#  'great_pyrenees_125.jpg': 'dog',
#  'great_pyrenees_126.jpg': 'dog',
#  'great_pyrenees_127.jpg': 'dog',
#  'great_pyrenees_128.jpg': 'dog',
#  'great_pyrenees_129.jpg': 'dog',
#  'great_pyrenees_12.jpg': 'dog',
#  'great_pyrenees_130.jpg': 'dog',
#  'great_pyrenees_131.jpg': 'dog',
#  'great_pyrenees_132.jpg': 'dog',
#  'great_pyrenees_133.jpg': 'dog',
#  'great_pyrenees_134.jpg': 'dog',
#  'great_pyrenees_135.jpg': 'dog',
#  'great_pyrenees_136.jpg': 'dog',
#  'great_pyrenees_137.jpg': 'dog',
#  'great_pyrenees_138.jpg': 'dog',
#  'great_pyrenees_139.jpg': 'dog',
#  'great_pyrenees_13.jpg': 'dog',
#  'great_pyrenees_140.jpg': 'dog',
#  'great_pyrenees_141.jpg': 'dog',
#  'great_pyrenees_142.jpg': 'dog',
#  'great_pyrenees_143.jpg': 'dog',
#  'great_pyrenees_144.jpg': 'dog',
#  'great_pyrenees_145.jpg': 'dog',
#  'havanese_100.jpg': 'dog',
#  'havanese_101.jpg': 'dog',
#  'havanese_102.jpg': 'dog',
#  'havanese_103.jpg': 'dog',
#  'havanese_104.jpg': 'dog',
#  'havanese_105.jpg': 'dog',
#  'havanese_106.jpg': 'dog',
#  'havanese_107.jpg': 'dog',
#  'havanese_108.jpg': 'dog',
#  'havanese_109.jpg': 'dog',
#  'havanese_10.jpg': 'dog',
#  'havanese_110.jpg': 'dog',
#  'havanese_111.jpg': 'dog',
#  'havanese_112.jpg': 'dog',
#  'havanese_113.jpg': 'dog',
#  'havanese_114.jpg': 'dog',
#  'havanese_115.jpg': 'dog',
#  'havanese_116.jpg': 'dog',
#  'havanese_117.jpg': 'dog',
#  'havanese_118.jpg': 'dog',
#  'havanese_119.jpg': 'dog',
#  'havanese_11.jpg': 'dog',
#  'havanese_120.jpg': 'dog',
#  'havanese_121.jpg': 'dog',
#  'havanese_122.jpg': 'dog',
#  'havanese_123.jpg': 'dog',
#  'havanese_124.jpg': 'dog',
#  'havanese_125.jpg': 'dog',
#  'havanese_126.jpg': 'dog',
#  'havanese_127.jpg': 'dog',
#  'havanese_128.jpg': 'dog',
#  'havanese_129.jpg': 'dog',
#  'havanese_12.jpg': 'dog',
#  'havanese_130.jpg': 'dog',
#  'havanese_131.jpg': 'dog',
#  'havanese_132.jpg': 'dog',
#  'havanese_133.jpg': 'dog',
#  'havanese_134.jpg': 'dog',
#  'havanese_135.jpg': 'dog',
#  'havanese_136.jpg': 'dog',
#  'havanese_137.jpg': 'dog',
#  'havanese_138.jpg': 'dog',
#  'havanese_139.jpg': 'dog',
#  'havanese_13.jpg': 'dog',
#  'havanese_140.jpg': 'dog',
#  'havanese_141.jpg': 'dog',
#  'havanese_142.jpg': 'dog',
#  'havanese_143.jpg': 'dog',
#  'havanese_144.jpg': 'dog',
#  'havanese_145.jpg': 'dog',
#  'japanese_chin_100.jpg': 'dog',
#  'japanese_chin_101.jpg': 'dog',
#  'japanese_chin_102.jpg': 'dog',
#  'japanese_chin_103.jpg': 'dog',
#  'japanese_chin_104.jpg': 'dog',
#  'japanese_chin_105.jpg': 'dog',
#  'japanese_chin_106.jpg': 'dog',
#  'japanese_chin_107.jpg': 'dog',
#  'japanese_chin_108.jpg': 'dog',
#  'japanese_chin_109.jpg': 'dog',
#  'japanese_chin_10.jpg': 'dog',
#  'japanese_chin_110.jpg': 'dog',
#  'japanese_chin_111.jpg': 'dog',
#  'japanese_chin_112.jpg': 'dog',
#  'japanese_chin_113.jpg': 'dog',
#  'japanese_chin_114.jpg': 'dog',
#  'japanese_chin_115.jpg': 'dog',
#  'japanese_chin_116.jpg': 'dog',
#  'japanese_chin_117.jpg': 'dog',
#  'japanese_chin_118.jpg': 'dog',
#  'japanese_chin_119.jpg': 'dog',
#  'japanese_chin_11.jpg': 'dog',
#  'japanese_chin_120.jpg': 'dog',
#  'japanese_chin_121.jpg': 'dog',
#  'japanese_chin_122.jpg': 'dog',
#  'japanese_chin_123.jpg': 'dog',
#  'japanese_chin_124.jpg': 'dog',
#  'japanese_chin_125.jpg': 'dog',
#  'japanese_chin_126.jpg': 'dog',
#  'japanese_chin_127.jpg': 'dog',
#  'japanese_chin_128.jpg': 'dog',
#  'japanese_chin_129.jpg': 'dog',
#  'japanese_chin_12.jpg': 'dog',
#  'japanese_chin_130.jpg': 'dog',
#  'japanese_chin_131.jpg': 'dog',
#  'japanese_chin_132.jpg': 'dog',
#  'japanese_chin_133.jpg': 'dog',
#  'japanese_chin_134.jpg': 'dog',
#  'japanese_chin_135.jpg': 'dog',
#  'japanese_chin_136.jpg': 'dog',
#  'japanese_chin_137.jpg': 'dog',
#  'japanese_chin_138.jpg': 'dog',
#  'japanese_chin_139.jpg': 'dog',
#  'japanese_chin_13.jpg': 'dog',
#  'japanese_chin_140.jpg': 'dog',
#  'japanese_chin_141.jpg': 'dog',
#  'japanese_chin_142.jpg': 'dog',
#  'japanese_chin_143.jpg': 'dog',
#  'japanese_chin_144.jpg': 'dog',
#  'japanese_chin_145.jpg': 'dog',
#  'keeshond_100.jpg': 'dog',
#  'keeshond_101.jpg': 'dog',
#  'keeshond_102.jpg': 'dog',
#  'keeshond_103.jpg': 'dog',
#  'keeshond_104.jpg': 'dog',
#  'keeshond_105.jpg': 'dog',
#  'keeshond_106.jpg': 'dog',
#  'keeshond_107.jpg': 'dog',
#  'keeshond_108.jpg': 'dog',
#  'keeshond_109.jpg': 'dog',
#  'keeshond_10.jpg': 'dog',
#  'keeshond_110.jpg': 'dog',
#  'keeshond_111.jpg': 'dog',
#  'keeshond_112.jpg': 'dog',
#  'keeshond_113.jpg': 'dog',
#  'keeshond_114.jpg': 'dog',
#  'keeshond_115.jpg': 'dog',
#  'keeshond_116.jpg': 'dog',
#  'keeshond_117.jpg': 'dog',
#  'keeshond_118.jpg': 'dog',
#  'keeshond_119.jpg': 'dog',
#  'keeshond_11.jpg': 'dog',
#  'keeshond_120.jpg': 'dog',
#  'keeshond_121.jpg': 'dog',
#  'keeshond_122.jpg': 'dog',
#  'keeshond_123.jpg': 'dog',
#  'keeshond_124.jpg': 'dog',
#  'keeshond_125.jpg': 'dog',
#  'keeshond_126.jpg': 'dog',
#  'keeshond_127.jpg': 'dog',
#  'keeshond_128.jpg': 'dog',
#  'keeshond_129.jpg': 'dog',
#  'keeshond_12.jpg': 'dog',
#  'keeshond_130.jpg': 'dog',
#  'keeshond_131.jpg': 'dog',
#  'keeshond_132.jpg': 'dog',
#  'keeshond_133.jpg': 'dog',
#  'keeshond_134.jpg': 'dog',
#  'keeshond_135.jpg': 'dog',
#  'keeshond_136.jpg': 'dog',
#  'keeshond_137.jpg': 'dog',
#  'keeshond_138.jpg': 'dog',
#  'keeshond_139.jpg': 'dog',
#  'keeshond_13.jpg': 'dog',
#  'keeshond_140.jpg': 'dog',
#  'keeshond_141.jpg': 'dog',
#  'keeshond_142.jpg': 'dog',
#  'keeshond_143.jpg': 'dog',
#  'keeshond_144.jpg': 'dog',
#  'keeshond_145.jpg': 'dog',
#  'leonberger_100.jpg': 'dog',
#  'leonberger_101.jpg': 'dog',
#  'leonberger_102.jpg': 'dog',
#  'leonberger_103.jpg': 'dog',
#  'leonberger_104.jpg': 'dog',
#  'leonberger_105.jpg': 'dog',
#  'leonberger_106.jpg': 'dog',
#  'leonberger_107.jpg': 'dog',
#  'leonberger_108.jpg': 'dog',
#  'leonberger_109.jpg': 'dog',
#  'leonberger_10.jpg': 'dog',
#  'leonberger_110.jpg': 'dog',
#  'leonberger_111.jpg': 'dog',
#  'leonberger_112.jpg': 'dog',
#  'leonberger_113.jpg': 'dog',
#  'leonberger_114.jpg': 'dog',
#  'leonberger_115.jpg': 'dog',
#  'leonberger_116.jpg': 'dog',
#  'leonberger_117.jpg': 'dog',
#  'leonberger_118.jpg': 'dog',
#  'leonberger_119.jpg': 'dog',
#  'leonberger_11.jpg': 'dog',
#  'leonberger_120.jpg': 'dog',
#  'leonberger_121.jpg': 'dog',
#  'leonberger_122.jpg': 'dog',
#  'leonberger_123.jpg': 'dog',
#  'leonberger_124.jpg': 'dog',
#  'leonberger_125.jpg': 'dog',
#  'leonberger_126.jpg': 'dog',
#  'leonberger_127.jpg': 'dog',
#  'leonberger_128.jpg': 'dog',
#  'leonberger_129.jpg': 'dog',
#  'leonberger_12.jpg': 'dog',
#  'leonberger_130.jpg': 'dog',
#  'leonberger_131.jpg': 'dog',
#  'leonberger_132.jpg': 'dog',
#  'leonberger_133.jpg': 'dog',
#  'leonberger_134.jpg': 'dog',
#  'leonberger_135.jpg': 'dog',
#  'leonberger_136.jpg': 'dog',
#  'leonberger_137.jpg': 'dog',
#  'leonberger_138.jpg': 'dog',
#  'leonberger_139.jpg': 'dog',
#  'leonberger_13.jpg': 'dog',
#  'leonberger_140.jpg': 'dog',
#  'leonberger_141.jpg': 'dog',
#  'leonberger_142.jpg': 'dog',
#  'leonberger_143.jpg': 'dog',
#  'leonberger_144.jpg': 'dog',
#  'leonberger_145.jpg': 'dog',
#  'Maine_Coon_100.jpg': 'cat',
#  'Maine_Coon_101.jpg': 'cat',
#  'Maine_Coon_102.jpg': 'cat',
#  'Maine_Coon_103.jpg': 'cat',
#  ...}

# %% [markdown]
# # Task 3: Get Random Batch

# %%
def get_random_batch(annot, image_dir='data/images/', batch_size=4):
    all_keys = list(annot.keys())
    total_examples = len(all_keys)
    
    indices = np.random.choice(range(total_examples), batch_size)
    x = np.zeros((batch_size, 128, 128, 3))
    y = np.zeros((batch_size, 1))
    images = []
    for i, index in enumerate(indices):
        image_path = os.path.join(image_dir, all_keys[index])
        image = tf.keras.preprocessing.image.load_img(
                image_path, target_size=(128, 128)
        )
        arr = tf.keras.preprocessing.image.img_to_array(image)
        arr = tf.keras.applications.mobilenet_v2.preprocess_input(arr)
        arr = np.expand_dims(arr, axis=0) # Optional
        x[i] = arr
        y[i] = class_to_index[annot[all_keys[index]]]
        images.append(image)
    return x, y, images

# %%
x, y, images = get_random_batch(train_annot, batch_size=8)
pets.display_examples(x, y, y, images, index_to_class).show()
# Out:
# Displaying first 8 examples..

# %% [markdown]
# # Task 4: Create Model

# %%
mnet = tf.keras.applications.mobilenet_v2.MobileNetV2(
    include_top=False,
    pooling='avg',
    weights='imagenet',
    input_shape=(128, 128, 3)
)
mnet.summary()
# Out:
# Model: "mobilenetv2_1.00_128"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 129, 129, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 64, 64, 32)   864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 64, 64, 32)   128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 64, 64, 32)   0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 64, 64, 32)   288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 64, 64, 32)   128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 64, 64, 32)   0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 64, 64, 16)   512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 64, 64, 16)   64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 64, 64, 96)   1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 64, 64, 96)   384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 64, 64, 96)   0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 65, 65, 96)   0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 32, 32, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 32, 32, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 32, 32, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 32, 32, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 32, 32, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 32, 32, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 32, 32, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 32, 32, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 32, 32, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 32, 32, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 32, 32, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 32, 32, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 32, 32, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 32, 32, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 32, 32, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 32, 32, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 32, 32, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 33, 33, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 16, 16, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 16, 16, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 16, 16, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 16, 16, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 16, 16, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 16, 16, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 16, 16, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 16, 16, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 16, 16, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 16, 16, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 16, 16, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 16, 16, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 16, 16, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 16, 16, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 16, 16, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 16, 16, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 16, 16, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 16, 16, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 16, 16, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 16, 16, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 16, 16, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 16, 16, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 16, 16, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 16, 16, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 16, 16, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 16, 16, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 17, 17, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 8, 8, 192)    1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 8, 8, 192)    768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 8, 8, 192)    0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 8, 8, 64)     12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 8, 8, 64)     256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 8, 8, 384)    24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 8, 8, 384)    1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 8, 8, 384)    0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 8, 8, 384)    3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 8, 8, 384)    1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 8, 8, 384)    0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 8, 8, 64)     24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 8, 8, 64)     256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 8, 8, 64)     0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 8, 8, 384)    24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 8, 8, 384)    1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 8, 8, 384)    0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 8, 8, 384)    3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 8, 8, 384)    1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 8, 8, 384)    0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 8, 8, 64)     24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 8, 8, 64)     256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 8, 8, 64)     0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 8, 8, 384)    24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 8, 8, 384)    1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 8, 8, 384)    0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 8, 8, 384)    3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 8, 8, 384)    1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 8, 8, 384)    0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 8, 8, 64)     24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 8, 8, 64)     256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 8, 8, 64)     0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 8, 8, 384)    24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 8, 8, 384)    1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 8, 8, 384)    0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 8, 8, 384)    3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 8, 8, 384)    1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 8, 8, 384)    0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 8, 8, 96)     36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 8, 8, 96)     384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 8, 8, 576)    55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 8, 8, 576)    2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 8, 8, 576)    0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 8, 8, 576)    5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 8, 8, 576)    2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 8, 8, 576)    0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 8, 8, 96)     55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 8, 8, 96)     384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 8, 8, 96)     0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 8, 8, 576)    55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 8, 8, 576)    2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 8, 8, 576)    0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 8, 8, 576)    5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 8, 8, 576)    2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 8, 8, 576)    0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 8, 8, 96)     55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 8, 8, 96)     384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 8, 8, 96)     0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 8, 8, 576)    55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 8, 8, 576)    2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 8, 8, 576)    0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 9, 9, 576)    0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 4, 4, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 4, 4, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 4, 4, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 4, 4, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 4, 4, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 4, 4, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 4, 4, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 4, 4, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 4, 4, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 4, 4, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 4, 4, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 4, 4, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 4, 4, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 4, 4, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 4, 4, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 4, 4, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 4, 4, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 4, 4, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 4, 4, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 4, 4, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 4, 4, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 4, 4, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 4, 4, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 4, 4, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 4, 4, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 4, 4, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 4, 4, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 4, 4, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 4, 4, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 4, 4, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 4, 4, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 4, 4, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 4, 4, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 4, 4, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           out_relu[0][0]
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
def create_model():
    model = tf.keras.models.Sequential([
        mnet,
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.layers[0].trainable=False
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', tf.keras.metrics.AUC()])
    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_128 (Model) (None, 1280)              2257984
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1281
# =================================================================
# Total params: 2,259,265
# Trainable params: 1,281
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# # Task 5: Model Training

# %%
def data_generator(batch_size, annot):
    while True:
        x, y, _ = get_random_batch(annot=annot, batch_size=batch_size)
        yield(x, y)

# %%
batch_size = 32
steps_per_epoch = int(count_train/batch_size)
validation_steps = int(count_test/batch_size)

print("Training steps:", steps_per_epoch)
print("Validation steps:", validation_steps)
# Out:
# Training steps: 115
# Validation steps: 114

# %%
# %%time
_ = model.fit_generator(
    data_generator(batch_size, train_annot),
    validation_data=data_generator(batch_size, test_annot),
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    epochs=1
)
# Out:
# 115/115 [==============================] - 1143s 10s/step - loss: 0.4195 - accuracy: 0.8008 - auc: 0.8650 - val_loss: 0.1333 - val_accuracy: 0.9641 - val_auc: 0.9877
# Wall time: 19min 3s

# %% [markdown]
# # Task 6: Predictions

# %%
x, y, images = get_random_batch(annot=test_annot, batch_size=8)
preds = model.predict(x)

# %%
pets.display_examples(x, y, preds, images, index_to_class).show()
# Out:
# Displaying first 8 examples..
